# %% [markdown]
# ****Transitive nodes**** consist of bidirectionally connected nodes which are used as anchors to retreive additional set of users with reciprocal ties, hence culminating to transitive relations.

# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import json, time, os, re

# %%
# ... a collection of nodes with transitive reciprocal ties.
df = pd.read_csv('data/nodes_with_simmelian_ties.csv')
len(df); df.head()
# Out:
#   G2_Anchor                             Lineage              BuddyID  \
# 0  vmochama   genna_buck:vmochama:alexgpaterson             16711211
# 1  vmochama  genna_buck:vmochama:ShelleyBFarmer   839456750000558080
# 2  vmochama      genna_buck:vmochama:amydempsey             21677048
# 3  vmochama        genna_buck:vmochama:JakePyne  1041790149925851136
# 4  vmochama   genna_buck:vmochama:TurnbullSarah            355132182
#
#   BuddyScreenName  BuddyFriends  BuddyFollowers
# 0   alexgpaterson           993             920
# 1  ShelleyBFarmer          1118            1364
# 2      amydempsey          1263            3749
# 3        JakePyne           999            1591
# 4   TurnbullSarah          1258             827

# %% [markdown]
# **Some examples:** In the following three dataframes, collection of related pairs results in transitive ties. Depending on which node is used in identifying reciprocal ties, the nodes are given in the form of generations spanning the following triplets: $parent:child:grandchild$ ... In the forthcoming examples (and the previous ones), the values in the dataframes are connected to the first generation anchors (G1_Anchor), to second generation anchor (G2_Anchor) via the parent nodes.
#     # ... collection of dyads from transitive set

# %%
#Reciprocal ties in unverified users category:
df = pd.read_csv('data/reciprocal_ties_in_unverified_anchors.csv')
len(df); df.head()
# Out:
#            ScreenName  FollowersCount  FriendsCount  \
# 369      GMan82721611             273           585
# 152          jjpaldad              92           130
# 546   bordersnbetween             502          1270
# 1745      monica_remy            3353          4172
# 545        editions_g               4             5
#
#                               Lineage  Status  Class  NetworkSize  Indegree  \
# 369         jackcade1381:GMan82721611   Child      1          858  0.318182
# 152                               NaN  Parent      1          222  0.414414
# 546   FredSeguinPhoto:bordersnbetween   Child      1         1772  0.283296
# 1745      ModernBullWagyu:monica_remy   Child      1         7525  0.445581
# 545        FredSeguinPhoto:editions_g   Child      1            9  0.444444
#
#       Outdegree
# 369    0.681818
# 152    0.585586
# 546    0.716704
# 1745   0.554419
# 545    0.555556

# %%
# Reciprocal ties in verified users category:
df = pd.read_csv('data/reciprocal_ties_in_verified_anchors.csv')
len(df); df.head()
# Out:
#       G3_Anchor    ChildID ChildScreenName                     Lineage  \
# 0    amydempsey  119818938    ZosiaBielski     amydempsey:ZosiaBielski
# 0     DACrosbie  197458714       DanDelmar         DACrosbie:DanDelmar
# 0  NickVanPraet  119818938    ZosiaBielski   NickVanPraet:ZosiaBielski
# 1  NickVanPraet   26505168     PaulJournet    NickVanPraet:PaulJournet
# 2  NickVanPraet   20423695   grassreporter  NickVanPraet:grassreporter
#
#    ChildFriends  ChildFollowers  PairwiseSize   Tracker
# 0           911            2588             1  (1, 999)
# 0           860            4666             1  (1, 999)
# 0           911            2588             3  (3, 997)
# 1          2130           40710             3  (3, 997)
# 2           862            7802             3  (3, 997)

# %% [markdown]
# **Example of the data structure** for training a prediction model ...

# %%
# set of directed nodes for training:
df = pd.read_csv('data/nodes_with_directed_ties.csv')
len(df); df.head()
# Out:
#                             Dyad               B1_ID B1_ScreenName  \
# 0  ('S4JJ40', 'Ghufran23924906')  744012835311730689        S4JJ40
# 1           ('S4JJ40', 'NajmRT')  744012835311730689        S4JJ40
# 2     ('S4JJ40', 'Fatabbayanoo')  744012835311730689        S4JJ40
# 3    ('S4JJ40', 'lk_bharmalani')  744012835311730689        S4JJ40
# 4       ('S4JJ40', 'baloghwaqt')  744012835311730689        S4JJ40
#
#           B1_CreatedAt  B1_Followers  B1_Friends  B1_Statuses  \
# 0  2016-06-18 03:44:17           983         433         1631
# 1  2016-06-18 03:44:17           983         433         1631
# 2  2016-06-18 03:44:17           983         433         1631
# 3  2016-06-18 03:44:17           983         433         1631
# 4  2016-06-18 03:44:17           983         433         1631
#
#                                       B1_Description        B1_Location  \
# 0  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏\nرَبَّنَا آتِنَا فِي الدُّنْ...  Kunar ~ Pekhawar
# 1  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏\nرَبَّنَا آتِنَا فِي الدُّنْ...  Kunar ~ Pekhawar
# 2  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏\nرَبَّنَا آتِنَا فِي الدُّنْ...  Kunar ~ Pekhawar
# 3  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏\nرَبَّنَا آتِنَا فِي الدُّنْ...  Kunar ~ Pekhawar
# 4  ‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏‏\nرَبَّنَا آتِنَا فِي الدُّنْ...  Kunar ~ Pekhawar
#
#    B1_Favourite  ...  B2_Statuses  \
# 0          2938  ...            4
# 1          2938  ...         2733
# 2          2938  ...           53
# 3          2938  ...           59
# 4          2938  ...           74
#
#                                       B2_Description  \
# 0                                                NaN
# 1  #Peace #Respect #love       .   Engineer #UETi...
# 2  Afghan / Durrani / Parsi Pataan 🏳🏴Youtube Has ...
# 3                                                NaN
# 4                                                 21
#
#                 B2_Location  B2_Favourite  B2_Verification  \
# 0                       NaN             3            False
# 1                       NaN          1909            False
# 2  Graveyard Of SuperPowers             1            False
# 3                     India           201            False
# 4                       NaN           568            False
#
#                                             B2_Tweet    B2_AccountCreated  \
# 0  RT @INReunification: Holi at Quaid-i-Azam Univ...  2019-03-25 19:49:51
# 1  Some Lucky Cats in Baitullah Makkah 😻 https://...  2019-04-15 15:39:22
# 2  Fatabayanoo Productions         Afghan Nasheed...  2019-04-16 09:46:23
# 3  Teri Mitti Female Version - Kesari - Arko feat...  2019-04-16 09:45:52
# 4  RT @xymtaco: Islam is evolutionary superior an...  2019-04-16 01:28:51
#
#    B2_RTCount    Status  Class
# 0        84.0  Directed      0
# 1         0.0  Directed      0
# 2         0.0  Directed      0
# 3         1.0  Directed      0
# 4         8.0  Directed      0
#
# [5 rows x 29 columns]

# %% [markdown]
# **See details in:**
# * Inuwa-Dutse I., Liptrott M., Korkontzelos Y. (2019) Simmelian ties on Twitter: empirical analysis and prediction. *The Sixth IEEE International Conference on Social Networks Analysis, Management and Security,* SNAMS-2019, Granada

# %%
### Collection of Simmelian Ties Data
